# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_parquet('../../data/train.parquet')

# %%
df.head()
# Out:
#                    era data_type  feature_shaded_hallucinatory_dactylology
# id
# n0007b5abb0c3a25  0001     train                                         3  \
# n003bba8a98662e4  0001     train                                         4
# n003bee128c2fcfc  0001     train                                         2
# n0048ac83aff7194  0001     train                                         2
# n0055a2401ba6480  0001     train                                         4
#
#                   feature_itinerant_hexahedral_photoengraver
# id
# n0007b5abb0c3a25                                           4  \
# n003bba8a98662e4                                           2
# n003bee128c2fcfc                                           4
# n0048ac83aff7194                                           1
# n0055a2401ba6480                                           1
#
#                   feature_prudent_pileate_oven
# id
# n0007b5abb0c3a25                             0  \
# n003bba8a98662e4                             4
# n003bee128c2fcfc                             0
# n0048ac83aff7194                             3
# n0055a2401ba6480                             4
#
#                   feature_subalpine_apothegmatical_ajax
# id
# n0007b5abb0c3a25                                      3  \
# n003bba8a98662e4                                      4
# n003bee128c2fcfc                                      3
# n0048ac83aff7194                                      0
# n0055a2401ba6480                                      1
#
#                   feature_pistachio_atypical_malison
# id
# n0007b5abb0c3a25                                   3  \
# n003bba8a98662e4                                   0
# n003bee128c2fcfc                                   0
# n0048ac83aff7194                                   3
# n0055a2401ba6480                                   0
#
#                   feature_symmetrical_spongy_tricentenary
# id
# n0007b5abb0c3a25                                        1  \
# n003bba8a98662e4                                        0
# n003bee128c2fcfc                                        3
# n0048ac83aff7194                                        0
# n0055a2401ba6480                                        4
#
#                   feature_ungrounded_transpontine_winder
# id
# n0007b5abb0c3a25                                       1  \
# n003bba8a98662e4                                       4
# n003bee128c2fcfc                                       2
# n0048ac83aff7194                                       3
# n0055a2401ba6480                                       0
#
#                   feature_aseptic_eely_hemiplegia  ...  target_teager2b_20
# id                                                 ...
# n0007b5abb0c3a25                                0  ...                0.50  \
# n003bba8a98662e4                                4  ...                0.50
# n003bee128c2fcfc                                4  ...                1.00
# n0048ac83aff7194                                3  ...                0.25
# n0055a2401ba6480                                4  ...                0.50
#
#                   target_teager2b_60  target_tyler_20  target_tyler_60
# id
# n0007b5abb0c3a25                0.50             0.25             0.25  \
# n003bba8a98662e4                0.50             0.25             0.25
# n003bee128c2fcfc                1.00             1.00             0.75
# n0048ac83aff7194                0.25             0.25             0.25
# n0055a2401ba6480                0.50             0.25             0.50
#
#                   target_victor_20  target_victor_60  target_waldo_20
# id
# n0007b5abb0c3a25              0.25              0.25             0.25  \
# n003bba8a98662e4              0.25              0.00             0.25
# n003bee128c2fcfc              0.75              0.75             0.75
# n0048ac83aff7194              0.50              0.25             0.25
# n0055a2401ba6480              0.25              0.50             0.25
#
#                   target_waldo_60  target_xerxes_20  target_xerxes_60
# id
# n0007b5abb0c3a25             0.00              0.25              0.00
# n003bba8a98662e4             0.25              0.25              0.25
# n003bee128c2fcfc             1.00              0.75              0.75
# n0048ac83aff7194             0.25              0.25              0.25
# n0055a2401ba6480             0.50              0.25              0.50
#
# [5 rows x 2415 columns]

# %%
df['target'].value_counts()
# Out:
# target
# 0.50    1373108
# 0.25     550995
# 0.75     550373
# 1.00     136126
# 0.00     135668
# Name: count, dtype: int64

# %%
df['feature_aubusson_sapheaded_parasol']
# Out:
# id
# n0007b5abb0c3a25    2
# n003bba8a98662e4    2
# n003bee128c2fcfc    2
# n0048ac83aff7194    2
# n0055a2401ba6480    2
#                    ..
# nffcc1dbdf2212e6    1
# nffde3b371d67394    2
# nfff1a1111b35e84    0
# nfff2bd38e397265    0
# nfffed717119d633    2
# Name: feature_aubusson_sapheaded_parasol, Length: 2746270, dtype: int8

# %%
# Replace 'feature_name' with the actual feature you want to analyze
feature_name = 'haemostatic_pulpiest_pembroke'

# Display value counts
print(df[feature_name].value_counts())

# Plot histogram
df[feature_name].hist(bins=20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/github/dspro2/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/Documents/github/dspro2/.venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Documents/github/dspro2/.venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'haemostatic_pulpiest_pembroke'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 5
#       2 feature_name = 'haemostatic_pulpiest_pembroke'
#       4 # Display value counts
# ----> 5 print(df[feature_name].value_counts())
#       7 # Plot histogram
#       8 df[feature_name].hist(bins=20)
#
# File ~/Documents/github/dspro2/.venv/lib/python3.9/site-packages/pandas/core/frame.py:3760, in DataFrame.__getitem__(self, key)
#    3758 if self.columns.nlevels > 1:
#    3759     return self._getitem_multilevel(key)
# -> 3760 indexer = self.columns.get_loc(key)
#    3761 if is_integer(indexer):
#    3762     indexer = [indexer]
#
# File ~/Documents/github/dspro2/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'haemostatic_pulpiest_pembroke'
